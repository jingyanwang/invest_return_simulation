# %%
import os
import re
import pandas as pd
from pandasql import sqldf

pysqldf = lambda q: sqldf(q, globals())

# %%
ETF = 'NDX'
ETF_3x = 'TQQQ'

# %%
month_mapping = {
    "Jun":6,
    "May":5,
    "Apr":4,
    "Mar":3,
    "Feb":2,
    "Jan":1,
    "Dec":12,
    "Nov":11,
    "Oct":10,
    "Sep":9,
    "Aug":8,
    "Jul":7,
    }

def date_normalize(date):
    try:
        result = re.search(r'(?P<m>\d+)\/(?P<d>\d+)\/(?P<y>\d+)', date).groupdict()
        output = '%04d-%02d-%02d'%(
            int(result['y']),
            int(result['m']),
            int(result['d']),
            )
        return output
    except:
        pass
    try:
        parsing_result = re.search(r'(?P<m>[A-z]{3}) (?P<d>\d{2}) (?P<y>\d{4})', date).groupdict()
        parsing_result['m'] = month_mapping[parsing_result['m']]
        parsing_result['m'] = '%02d'%(parsing_result['m'])
        return('%s-%s-%s'%(
            parsing_result['y'],
            parsing_result['m'],
            parsing_result['d'],
            ))
    except:
        pass
    return date


date = '9/17/2015'
date = 'Jun 14 2022'

date_normalize(
    date,
    )
# Out:
# '2022-06-14'

# %%
final_result = pd.read_excel(
    '{}_leverage_simulation.xlsx'.format(ETF),
    )

# %%
final_result.head(3)
# Out:
#          Date         NDX  simulated_TQQQ  TQQQ  Unnamed: 4  Unnamed: 5  \
# 0  1985-10-02  110.824997        0.299116   NaN         NaN         NaN
# 1  1985-10-03  110.870003        0.299175   NaN         NaN         NaN
# 2  1985-10-04  110.074997        0.298136   NaN         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  percent    return
# 0         NaN         NaN         NaN         NaN     0.00  0.294430
# 1         NaN         NaN         NaN         NaN     0.25  0.710706
# 2         NaN         NaN         NaN         NaN     0.50  1.291388

# %% [markdown]
# # the return

# %%
daily_invest_amount = 1000

invest = pysqldf(u"""
    select 
    Date,
    {} AS price,
    case
        when {} is not null then {}
        else simulated_{}
    end as price_3x
    from final_result
    """.format(
        ETF,
        ETF_3x,
        ETF_3x,
        ETF_3x,
    ))

invest1 = pysqldf(u"""
    select *,
    {} as daily_invest_amount,
    {}/price as shares,
    {}/price_3x as shares_3x    
    from invest
    order by Date asc
    """.format(
    daily_invest_amount,
    daily_invest_amount,
    daily_invest_amount))

# %%
invest1.head(3)
# Out:
#          Date       price  price_3x  daily_invest_amount    shares  \
# 0  1985-10-02  110.824997  0.299116                 1000  9.023235
# 1  1985-10-03  110.870003  0.299175                 1000  9.019572
# 2  1985-10-04  110.074997  0.298136                 1000  9.084715
#
#      shares_3x
# 0  3343.180430
# 1  3342.523902
# 2  3354.168665

# %%
days_duration = int(10*250)

final_result['id'] = final_result.index

first_last_days = pysqldf(u"""
    select 
    f.Date as invest_date_first, 
    date_2500_days_later.Date as invest_date_last
    from final_result as f
    join final_result as date_2500_days_later on date_2500_days_later.id = f.id+{}
    """.format(days_duration)).to_dict('records')

print(days_duration)
# Out:
# 2500

# %%
returns = []

for r in first_last_days:
    invest_date_first = r['invest_date_first']
    invest_date_last = r['invest_date_last']
    
    print('processing data between {} and {}'.format(
    invest_date_first,
    invest_date_last,
    ))

    #invest_date_first = '2013-01-01'
    #invest_date_last = '2013-01-05'

    window = pysqldf(u"""
        select *
        from invest1
        where Date >= '{}'
        and Date <= '{}'
        """.format(
        invest_date_first, 
        invest_date_last
        ))

    total_df = pysqldf(u"""
        select 
        sum(daily_invest_amount) as invest_amount,
        sum(shares) as shares,
        sum(shares_3x) as shares_3x
        from window
        """)

    invest_amount = total_df['invest_amount'][0]
    shares = total_df['shares'][0]
    shares_3x = total_df['shares_3x'][0]

    ###

    first_date = pysqldf(u"""
        select *  
        from window
        order by Date asc
        limit 1
        """)

    first_price = first_date['price'][0]
    first_price_3x = first_date['price_3x'][0]

    last_date = pysqldf(u"""
        select *  
        from window
        order by Date desc
        limit 1
        """)

    last_price = last_date['price'][0]
    last_price_3x = last_date['price_3x'][0]

    ###

    all_in_return = last_price/first_price-1
    all_in_3x_return = last_price_3x/first_price_3x-1

    cost_averaging_return = shares*last_price/invest_amount-1
    cost_averaging_3x_return = shares_3x*last_price_3x/invest_amount-1

    record = {
        'invest_date_first':invest_date_first,
        'invest_date_last':invest_date_last,
        'all_in_return':all_in_return,
        'all_in_3x_return':all_in_3x_return,
        'cost_averaging_return':cost_averaging_return,
        'cost_averaging_3x_return':cost_averaging_3x_return,    
    }
    
    returns.append(record)


###    

returns_duration_df = pd.DataFrame(returns)

returns_duration_df.to_excel(
    '{}_returns_{}d.xlsx'.format(
        ETF,
        days_duration),
    index = False
    )
# Out:
# processing data between 1985-10-02 and 1995-08-22
# processing data between 1985-10-03 and 1995-08-23
# processing data between 1985-10-04 and 1995-08-24
# processing data between 1985-10-07 and 1995-08-25
# processing data between 1985-10-08 and 1995-08-28
# processing data between 1985-10-09 and 1995-08-29
# processing data between 1985-10-10 and 1995-08-30
# processing data between 1985-10-11 and 1995-08-31
# processing data between 1985-10-14 and 1995-09-01
# processing data between 1985-10-15 and 1995-09-05
# processing data between 1985-10-16 and 1995-09-06
# processing data between 1985-10-17 and 1995-09-07
# processing data between 1985-10-18 and 1995-09-08
# processing data between 1985-10-21 and 1995-09-11
# processing data between 1985-10-22 and 1995-09-12
# processing data between 1985-10-23 and 1995-09-13
# processing data between 1985-10-24 and 1995-09-14
# processing data between 1985-10-25 and 1995-09-15
# processing data between 1985-10-28 and 1995-09-18
# processing data between 1985-10-29 and 1995-09-19
# processing data between 1985-10-30 and 1995-09-20
# processing data between 1985-10-31 and 1995-09-21
# processing data between 1985-11-01 and 1995-09-22
# processing data between 1985-11-04 and 1995-09-25
# processing data between 1985-11-05 and 1995-09-26
# processing data between 1985-11-06 and 1995-09-27
# processing data between 1985-11-07 and 1995-09-28
# processing data between 1985-11-08 and 1995-09-29
# processing data between 1985-11-11 and 1995-10-02
# processing data between 1985-11-12 and 1995-10-03
# processing data between 1985-11-13 and 1995-10-04
# processing data between 1985-11-14 and 1995-10-05
# processing data between 1985-11-15 and 1995-10-06
# processing data between 1985-11-18 and 1995-10-09
# processing data between 1985-11-19 and 1995-10-10
# processing data between 1985-11-20 and 1995-10-11
# processing data between 1985-11-21 and 1995-10-12
# processing data between 1985-11-22 and 1995-10-13
# processing data between 1985-11-25 and 1995-10-16
# processing data between 1985-11-26 and 1995-10-17
# processing data between 1985-11-27 and 1995-10-18
# processing data between 1985-11-29 and 1995-10-19
# processing data between 1985-12-02 and 1995-10-20
# processing data between 1985-12-03 and 1995-10-23
# processing data between 1985-12-04 and 1995-10-24
# processing data between 1985-12-05 and 1995-10-25
# processing data between 1985-12-06 and 1995-10-26
# processing data between 1985-12-09 and 1995-10-27
# processing data between 1985-12-10 and 1995-10-30
# processing data between 1985-12-11 and 1995-10-31
# processing data between 1985-12-12 and 1995-11-01
# processing data between 1985-12-13 and 1995-11-02
# processing data between 1985-12-16 and 1995-11-03
# processing data between 1985-12-17 and 1995-11-06
# processing data between 1985-12-18 and 1995-11-07
# processing data between 1985-12-19 and 1995-11-08
# processing data between 1985-12-20 and 1995-11-09
# processing data between 1985-12-23 and 1995-11-10
# processing data between 1985-12-24 and 1995-11-13
# processing data between 1985-12-26 and 1995-11-14
# processing data between 1985-12-27 and 1995-11-15
# processing data between 1985-12-30 and 1995-11-16
# processing data between 1985-12-31 and 1995-11-17
# processing data between 1986-01-02 and 1995-11-20
# processing data between 1986-01-03 and 1995-11-21
# processing data between 1986-01-06 and 1995-11-22
# processing data between 1986-01-07 and 1995-11-24
# processing data between 1986-01-08 and 1995-11-27
# processing data between 1986-01-09 and 1995-11-28
# processing data between 1986-01-10 and 1995-11-29
# processing data between 1986-01-13 and 1995-11-30
# processing data between 1986-01-14 and 1995-12-01
# processing data between 1986-01-15 and 1995-12-04
# processing data between 1986-01-16 and 1995-12-05
# processing data between 1986-01-17 and 1995-12-06
# processing data between 1986-01-20 and 1995-12-07
# processing data between 1986-01-21 and 1995-12-08
# processing data between 1986-01-22 and 1995-12-11
# processing data between 1986-01-23 and 1995-12-12
# processing data between 1986-01-24 and 1995-12-13
# processing data between 1986-01-27 and 1995-12-14
# processing data between 1986-01-28 and 1995-12-15
# processing data between 1986-01-29 and 1995-12-18
# processing data between 1986-01-30 and 1995-12-19
# processing data between 1986-01-31 and 1995-12-20
# processing data between 1986-02-03 and 1995-12-21
# processing data between 1986-02-04 and 1995-12-22
# processing data between 1986-02-05 and 1995-12-26
# processing data between 1986-02-06 and 1995-12-27
# processing data between 1986-02-07 and 1995-12-28
# processing data between 1986-02-10 and 1995-12-29
# processing data between 1986-02-11 and 1996-01-02
# processing data between 1986-02-12 and 1996-01-03
# processing data between 1986-02-13 and 1996-01-04
# processing data between 1986-02-14 and 1996-01-05
# processing data between 1986-02-18 and 1996-01-08
# processing data between 1986-02-19 and 1996-01-09
# processing data between 1986-02-20 and 1996-01-10
# processing data between 1986-02-21 and 1996-01-11
# processing data between 1986-02-24 and 1996-01-12
# processing data between 1986-02-25 and 1996-01-15
# processing data between 1986-02-26 and 1996-01-16
# processing data between 1986-02-27 and 1996-01-17
# processing data between 1986-02-28 and 1996-01-18
# processing data between 1986-03-03 and 1996-01-19
# processing data between 1986-03-04 and 1996-01-22
# processing data between 1986-03-05 and 1996-01-23
# processing data between 1986-03-06 and 1996-01-24
# processing data between 1986-03-07 and 1996-01-25
# processing data between 1986-03-10 and 1996-01-26
# processing data between 1986-03-11 and 1996-01-29
# processing data between 1986-03-12 and 1996-01-30
# processing data between 1986-03-13 and 1996-01-31
# processing data between 1986-03-14 and 1996-02-01
# processing data between 1986-03-17 and 1996-02-02
# processing data between 1986-03-18 and 1996-02-05
# processing data between 1986-03-19 and 1996-02-06
# processing data between 1986-03-20 and 1996-02-07
# processing data between 1986-03-21 and 1996-02-08
# processing data between 1986-03-24 and 1996-02-09
# processing data between 1986-03-25 and 1996-02-12
# processing data between 1986-03-26 and 1996-02-13
# processing data between 1986-03-27 and 1996-02-14
# processing data between 1986-03-31 and 1996-02-15
# processing data between 1986-04-01 and 1996-02-16
# processing data between 1986-04-02 and 1996-02-20
# processing data between 1986-04-03 and 1996-02-21
# processing data between 1986-04-04 and 1996-02-22
# processing data between 1986-04-07 and 1996-02-23
# processing data between 1986-04-08 and 1996-02-26
# processing data between 1986-04-09 and 1996-02-27
# processing data between 1986-04-10 and 1996-02-28
# processing data between 1986-04-11 and 1996-02-29
# processing data between 1986-04-14 and 1996-03-01
# processing data between 1986-04-15 and 1996-03-04
# processing data between 1986-04-16 and 1996-03-05
# processing data between 1986-04-17 and 1996-03-06
# processing data between 1986-04-18 and 1996-03-07
# processing data between 1986-04-21 and 1996-03-08
# processing data between 1986-04-22 and 1996-03-11
# processing data between 1986-04-23 and 1996-03-12
# processing data between 1986-04-24 and 1996-03-13
# processing data between 1986-04-25 and 1996-03-14
# processing data between 1986-04-28 and 1996-03-15
# processing data between 1986-04-29 and 1996-03-18
# processing data between 1986-04-30 and 1996-03-19
# processing data between 1986-05-01 and 1996-03-20
# processing data between 1986-05-02 and 1996-03-21
# processing data between 1986-05-05 and 1996-03-22
# processing data between 1986-05-06 and 1996-03-25
# processing data between 1986-05-07 and 1996-03-26
# processing data between 1986-05-08 and 1996-03-27
# processing data between 1986-05-09 and 1996-03-28
# processing data between 1986-05-12 and 1996-03-29
# processing data between 1986-05-13 and 1996-04-01
# processing data between 1986-05-14 and 1996-04-02
# processing data between 1986-05-15 and 1996-04-03
# processing data between 1986-05-16 and 1996-04-04
# processing data between 1986-05-19 and 1996-04-08
# processing data between 1986-05-20 and 1996-04-09
# processing data between 1986-05-21 and 1996-04-10
# processing data between 1986-05-22 and 1996-04-11
# processing data between 1986-05-23 and 1996-04-12
# processing data between 1986-05-27 and 1996-04-15
# processing data between 1986-05-28 and 1996-04-16
# processing data between 1986-05-29 and 1996-04-17
# processing data between 1986-05-30 and 1996-04-18
# processing data between 1986-06-02 and 1996-04-19
# processing data between 1986-06-03 and 1996-04-22
# processing data between 1986-06-04 and 1996-04-23
# processing data between 1986-06-05 and 1996-04-24
# processing data between 1986-06-06 and 1996-04-25
# processing data between 1986-06-09 and 1996-04-26
# processing data between 1986-06-10 and 1996-04-29
# processing data between 1986-06-11 and 1996-04-30
# processing data between 1986-06-12 and 1996-05-01
# processing data between 1986-06-13 and 1996-05-02
# processing data between 1986-06-16 and 1996-05-03
# processing data between 1986-06-17 and 1996-05-06
# processing data between 1986-06-18 and 1996-05-07
# processing data between 1986-06-19 and 1996-05-08
# processing data between 1986-06-20 and 1996-05-09
# processing data between 1986-06-23 and 1996-05-10
# processing data between 1986-06-24 and 1996-05-13
# processing data between 1986-06-25 and 1996-05-14
# processing data between 1986-06-26 and 1996-05-15
# processing data between 1986-06-27 and 1996-05-16
# processing data between 1986-06-30 and 1996-05-17
# processing data between 1986-07-01 and 1996-05-20
# processing data between 1986-07-02 and 1996-05-21
# processing data between 1986-07-03 and 1996-05-22
# processing data between 1986-07-07 and 1996-05-23
# processing data between 1986-07-08 and 1996-05-24
# processing data between 1986-07-09 and 1996-05-28
# processing data between 1986-07-10 and 1996-05-29
# processing data between 1986-07-11 and 1996-05-30
# processing data between 1986-07-14 and 1996-05-31
# processing data between 1986-07-15 and 1996-06-03
# processing data between 1986-07-16 and 1996-06-04
# processing data between 1986-07-17 and 1996-06-05
# processing data between 1986-07-18 and 1996-06-06
# processing data between 1986-07-21 and 1996-06-07
# processing data between 1986-07-22 and 1996-06-10
# processing data between 1986-07-23 and 1996-06-11
# processing data between 1986-07-24 and 1996-06-12
# processing data between 1986-07-25 and 1996-06-13
# processing data between 1986-07-28 and 1996-06-14
# processing data between 1986-07-29 and 1996-06-17
# processing data between 1986-07-30 and 1996-06-18
# processing data between 1986-07-31 and 1996-06-19
# processing data between 1986-08-01 and 1996-06-20
# processing data between 1986-08-04 and 1996-06-21
# processing data between 1986-08-05 and 1996-06-24
# processing data between 1986-08-06 and 1996-06-25
# processing data between 1986-08-07 and 1996-06-26
# processing data between 1986-08-08 and 1996-06-27
# processing data between 1986-08-11 and 1996-06-28
# processing data between 1986-08-12 and 1996-07-01
# processing data between 1986-08-13 and 1996-07-02
# processing data between 1986-08-14 and 1996-07-03
# processing data between 1986-08-15 and 1996-07-05
# processing data between 1986-08-18 and 1996-07-08
# processing data between 1986-08-19 and 1996-07-09
# processing data between 1986-08-20 and 1996-07-10
# processing data between 1986-08-21 and 1996-07-11
# processing data between 1986-08-22 and 1996-07-12
# processing data between 1986-08-25 and 1996-07-15
# processing data between 1986-08-26 and 1996-07-16
# processing data between 1986-08-27 and 1996-07-17
# processing data between 1986-08-28 and 1996-07-18
# processing data between 1986-08-29 and 1996-07-19
# processing data between 1986-09-02 and 1996-07-22
# processing data between 1986-09-03 and 1996-07-23
# processing data between 1986-09-04 and 1996-07-24
# processing data between 1986-09-05 and 1996-07-25
# processing data between 1986-09-08 and 1996-07-26
# processing data between 1986-09-09 and 1996-07-29
# processing data between 1986-09-10 and 1996-07-30
# processing data between 1986-09-11 and 1996-07-31
# processing data between 1986-09-12 and 1996-08-01
# processing data between 1986-09-15 and 1996-08-02
# processing data between 1986-09-16 and 1996-08-05
# processing data between 1986-09-17 and 1996-08-06
# processing data between 1986-09-18 and 1996-08-07
# processing data between 1986-09-19 and 1996-08-08
# processing data between 1986-09-22 and 1996-08-09
# processing data between 1986-09-23 and 1996-08-12
# processing data between 1986-09-24 and 1996-08-13
# processing data between 1986-09-25 and 1996-08-14
# processing data between 1986-09-26 and 1996-08-15
# processing data between 1986-09-29 and 1996-08-16
# processing data between 1986-09-30 and 1996-08-19
# processing data between 1986-10-01 and 1996-08-20
# processing data between 1986-10-02 and 1996-08-21
# processing data between 1986-10-03 and 1996-08-22
# processing data between 1986-10-06 and 1996-08-23
# processing data between 1986-10-07 and 1996-08-26
# processing data between 1986-10-08 and 1996-08-27
# processing data between 1986-10-09 and 1996-08-28
# processing data between 1986-10-10 and 1996-08-29
# processing data between 1986-10-13 and 1996-08-30
# processing data between 1986-10-14 and 1996-09-03
# processing data between 1986-10-15 and 1996-09-04
# processing data between 1986-10-16 and 1996-09-05
# processing data between 1986-10-17 and 1996-09-06
# processing data between 1986-10-20 and 1996-09-09
# processing data between 1986-10-21 and 1996-09-10
# processing data between 1986-10-22 and 1996-09-11
# processing data between 1986-10-23 and 1996-09-12
# processing data between 1986-10-24 and 1996-09-13
# processing data between 1986-10-27 and 1996-09-16
# processing data between 1986-10-28 and 1996-09-17
# processing data between 1986-10-29 and 1996-09-18
# processing data between 1986-10-30 and 1996-09-19
# processing data between 1986-10-31 and 1996-09-20
# processing data between 1986-11-03 and 1996-09-23
# processing data between 1986-11-04 and 1996-09-24
# processing data between 1986-11-05 and 1996-09-25
# processing data between 1986-11-06 and 1996-09-26
# processing data between 1986-11-07 and 1996-09-27
# processing data between 1986-11-10 and 1996-09-30
# processing data between 1986-11-11 and 1996-10-01
# processing data between 1986-11-12 and 1996-10-02
# processing data between 1986-11-13 and 1996-10-03
# processing data between 1986-11-14 and 1996-10-04
# processing data between 1986-11-17 and 1996-10-07
# processing data between 1986-11-18 and 1996-10-08
# processing data between 1986-11-19 and 1996-10-09
# processing data between 1986-11-20 and 1996-10-10
# processing data between 1986-11-21 and 1996-10-11
# processing data between 1986-11-24 and 1996-10-14
# processing data between 1986-11-25 and 1996-10-15
# processing data between 1986-11-26 and 1996-10-16
# processing data between 1986-11-28 and 1996-10-17
# processing data between 1986-12-01 and 1996-10-18
# processing data between 1986-12-02 and 1996-10-21
# processing data between 1986-12-03 and 1996-10-22
# processing data between 1986-12-04 and 1996-10-23
# processing data between 1986-12-05 and 1996-10-24
# processing data between 1986-12-08 and 1996-10-25
# processing data between 1986-12-09 and 1996-10-28
# processing data between 1986-12-10 and 1996-10-29
# processing data between 1986-12-11 and 1996-10-30
# processing data between 1986-12-12 and 1996-10-31
# processing data between 1986-12-15 and 1996-11-01
# processing data between 1986-12-16 and 1996-11-04
# processing data between 1986-12-17 and 1996-11-05
# processing data between 1986-12-18 and 1996-11-06
# processing data between 1986-12-19 and 1996-11-07
# processing data between 1986-12-22 and 1996-11-08
# processing data between 1986-12-23 and 1996-11-11
# processing data between 1986-12-24 and 1996-11-12
# processing data between 1986-12-26 and 1996-11-13
# processing data between 1986-12-29 and 1996-11-14
# processing data between 1986-12-30 and 1996-11-15
# processing data between 1986-12-31 and 1996-11-18
# processing data between 1987-01-02 and 1996-11-19
# processing data between 1987-01-05 and 1996-11-20
# processing data between 1987-01-06 and 1996-11-21
# processing data between 1987-01-07 and 1996-11-22
# processing data between 1987-01-08 and 1996-11-25
# processing data between 1987-01-09 and 1996-11-26
# processing data between 1987-01-12 and 1996-11-27
# processing data between 1987-01-13 and 1996-11-29
# processing data between 1987-01-14 and 1996-12-02
# processing data between 1987-01-15 and 1996-12-03
# processing data between 1987-01-16 and 1996-12-04
# processing data between 1987-01-19 and 1996-12-05
# processing data between 1987-01-20 and 1996-12-06
# processing data between 1987-01-21 and 1996-12-09
# processing data between 1987-01-22 and 1996-12-10
# processing data between 1987-01-23 and 1996-12-11
# processing data between 1987-01-26 and 1996-12-12
# processing data between 1987-01-27 and 1996-12-13
# processing data between 1987-01-28 and 1996-12-16
# processing data between 1987-01-29 and 1996-12-17
# processing data between 1987-01-30 and 1996-12-18
# processing data between 1987-02-02 and 1996-12-19
# processing data between 1987-02-03 and 1996-12-20
# processing data between 1987-02-04 and 1996-12-23
# processing data between 1987-02-05 and 1996-12-24
# processing data between 1987-02-06 and 1996-12-26
# processing data between 1987-02-09 and 1996-12-27
# processing data between 1987-02-10 and 1996-12-30
# processing data between 1987-02-11 and 1996-12-31
# processing data between 1987-02-12 and 1997-01-02
# processing data between 1987-02-13 and 1997-01-03
# processing data between 1987-02-17 and 1997-01-06
# processing data between 1987-02-18 and 1997-01-07
# processing data between 1987-02-19 and 1997-01-08
# processing data between 1987-02-20 and 1997-01-09
# processing data between 1987-02-23 and 1997-01-10
# processing data between 1987-02-24 and 1997-01-13
# processing data between 1987-02-25 and 1997-01-14
# processing data between 1987-02-26 and 1997-01-15
# processing data between 1987-02-27 and 1997-01-16
# processing data between 1987-03-02 and 1997-01-17
# processing data between 1987-03-03 and 1997-01-20
# processing data between 1987-03-04 and 1997-01-21
# processing data between 1987-03-05 and 1997-01-22
# processing data between 1987-03-06 and 1997-01-23
# processing data between 1987-03-09 and 1997-01-24
# processing data between 1987-03-10 and 1997-01-27
# processing data between 1987-03-11 and 1997-01-28
# processing data between 1987-03-12 and 1997-01-29
# processing data between 1987-03-13 and 1997-01-30
# processing data between 1987-03-16 and 1997-01-31
# processing data between 1987-03-17 and 1997-02-03
# processing data between 1987-03-18 and 1997-02-04
# processing data between 1987-03-19 and 1997-02-05
# processing data between 1987-03-20 and 1997-02-06
# processing data between 1987-03-23 and 1997-02-07
# processing data between 1987-03-24 and 1997-02-10
# processing data between 1987-03-25 and 1997-02-11
# processing data between 1987-03-26 and 1997-02-12
# processing data between 1987-03-27 and 1997-02-13
# processing data between 1987-03-30 and 1997-02-14
# processing data between 1987-03-31 and 1997-02-18
# processing data between 1987-04-01 and 1997-02-19
# processing data between 1987-04-02 and 1997-02-20
# processing data between 1987-04-03 and 1997-02-21
# processing data between 1987-04-06 and 1997-02-24
# processing data between 1987-04-07 and 1997-02-25
# processing data between 1987-04-08 and 1997-02-26
# processing data between 1987-04-09 and 1997-02-27
# processing data between 1987-04-10 and 1997-02-28
# processing data between 1987-04-13 and 1997-03-03
# processing data between 1987-04-14 and 1997-03-04
# processing data between 1987-04-15 and 1997-03-05
# processing data between 1987-04-16 and 1997-03-06
# processing data between 1987-04-20 and 1997-03-07
# processing data between 1987-04-21 and 1997-03-10
# processing data between 1987-04-22 and 1997-03-11
# processing data between 1987-04-23 and 1997-03-12
# processing data between 1987-04-24 and 1997-03-13
# processing data between 1987-04-27 and 1997-03-14
# processing data between 1987-04-28 and 1997-03-17
# processing data between 1987-04-29 and 1997-03-18
# processing data between 1987-04-30 and 1997-03-19
# processing data between 1987-05-01 and 1997-03-20
# processing data between 1987-05-04 and 1997-03-21
# processing data between 1987-05-05 and 1997-03-24
# processing data between 1987-05-06 and 1997-03-25
# processing data between 1987-05-07 and 1997-03-26
# processing data between 1987-05-08 and 1997-03-27
# processing data between 1987-05-11 and 1997-03-31
# processing data between 1987-05-12 and 1997-04-01
# processing data between 1987-05-13 and 1997-04-02
# processing data between 1987-05-14 and 1997-04-03
# processing data between 1987-05-15 and 1997-04-04
# processing data between 1987-05-18 and 1997-04-07
# processing data between 1987-05-19 and 1997-04-08
# processing data between 1987-05-20 and 1997-04-09
# processing data between 1987-05-21 and 1997-04-10
# processing data between 1987-05-22 and 1997-04-11
# processing data between 1987-05-26 and 1997-04-14
# processing data between 1987-05-27 and 1997-04-15
# processing data between 1987-05-28 and 1997-04-16
# processing data between 1987-05-29 and 1997-04-17
# processing data between 1987-06-01 and 1997-04-18
# processing data between 1987-06-02 and 1997-04-21
# processing data between 1987-06-03 and 1997-04-22
# processing data between 1987-06-04 and 1997-04-23
# processing data between 1987-06-05 and 1997-04-24
# processing data between 1987-06-08 and 1997-04-25
# processing data between 1987-06-09 and 1997-04-28
# processing data between 1987-06-10 and 1997-04-29
# processing data between 1987-06-11 and 1997-04-30
# processing data between 1987-06-12 and 1997-05-01
# processing data between 1987-06-15 and 1997-05-02
# processing data between 1987-06-16 and 1997-05-05
# processing data between 1987-06-17 and 1997-05-06
# processing data between 1987-06-18 and 1997-05-07
# processing data between 1987-06-19 and 1997-05-08
# processing data between 1987-06-22 and 1997-05-09
# processing data between 1987-06-23 and 1997-05-12
# processing data between 1987-06-24 and 1997-05-13
# processing data between 1987-06-25 and 1997-05-14
# processing data between 1987-06-26 and 1997-05-15
# processing data between 1987-06-29 and 1997-05-16
# processing data between 1987-06-30 and 1997-05-19
# processing data between 1987-07-01 and 1997-05-20
# processing data between 1987-07-02 and 1997-05-21
# processing data between 1987-07-06 and 1997-05-22
# processing data between 1987-07-07 and 1997-05-23
# processing data between 1987-07-08 and 1997-05-27
# processing data between 1987-07-09 and 1997-05-28
# processing data between 1987-07-10 and 1997-05-29
# processing data between 1987-07-13 and 1997-05-30
# processing data between 1987-07-14 and 1997-06-02
# processing data between 1987-07-15 and 1997-06-03
# processing data between 1987-07-16 and 1997-06-04
# processing data between 1987-07-17 and 1997-06-05
# processing data between 1987-07-20 and 1997-06-06
# processing data between 1987-07-21 and 1997-06-09
# processing data between 1987-07-22 and 1997-06-10
# processing data between 1987-07-23 and 1997-06-11
# processing data between 1987-07-24 and 1997-06-12
# processing data between 1987-07-27 and 1997-06-13
# processing data between 1987-07-28 and 1997-06-16
# processing data between 1987-07-29 and 1997-06-17
# processing data between 1987-07-30 and 1997-06-18
# processing data between 1987-07-31 and 1997-06-19
# processing data between 1987-08-03 and 1997-06-20
# processing data between 1987-08-04 and 1997-06-23
# processing data between 1987-08-05 and 1997-06-24
# processing data between 1987-08-06 and 1997-06-25
# processing data between 1987-08-07 and 1997-06-26
# processing data between 1987-08-10 and 1997-06-27
# processing data between 1987-08-11 and 1997-06-30
# processing data between 1987-08-12 and 1997-07-01
# processing data between 1987-08-13 and 1997-07-02
# processing data between 1987-08-14 and 1997-07-03
# processing data between 1987-08-17 and 1997-07-07
# processing data between 1987-08-18 and 1997-07-08
# processing data between 1987-08-19 and 1997-07-09
# processing data between 1987-08-20 and 1997-07-10
# processing data between 1987-08-21 and 1997-07-11
# processing data between 1987-08-24 and 1997-07-14
# processing data between 1987-08-25 and 1997-07-15
# processing data between 1987-08-26 and 1997-07-16
# processing data between 1987-08-27 and 1997-07-17
# processing data between 1987-08-28 and 1997-07-18
# processing data between 1987-08-31 and 1997-07-21
# processing data between 1987-09-01 and 1997-07-22
# processing data between 1987-09-02 and 1997-07-23
# processing data between 1987-09-03 and 1997-07-24
# processing data between 1987-09-04 and 1997-07-25
# processing data between 1987-09-08 and 1997-07-28
# processing data between 1987-09-09 and 1997-07-29
# processing data between 1987-09-10 and 1997-07-30
# processing data between 1987-09-11 and 1997-07-31
# processing data between 1987-09-14 and 1997-08-01
# processing data between 1987-09-15 and 1997-08-04
# processing data between 1987-09-16 and 1997-08-05
# processing data between 1987-09-17 and 1997-08-06
# processing data between 1987-09-18 and 1997-08-07
# processing data between 1987-09-21 and 1997-08-08
# processing data between 1987-09-22 and 1997-08-11
# processing data between 1987-09-23 and 1997-08-12
# processing data between 1987-09-24 and 1997-08-13
# processing data between 1987-09-25 and 1997-08-14
# processing data between 1987-09-28 and 1997-08-15
# processing data between 1987-09-29 and 1997-08-18
# processing data between 1987-09-30 and 1997-08-19
# processing data between 1987-10-01 and 1997-08-20
# processing data between 1987-10-02 and 1997-08-21
# processing data between 1987-10-05 and 1997-08-22
# processing data between 1987-10-06 and 1997-08-25
# processing data between 1987-10-07 and 1997-08-26
# processing data between 1987-10-08 and 1997-08-27
# processing data between 1987-10-09 and 1997-08-28
# processing data between 1987-10-12 and 1997-08-29
# processing data between 1987-10-13 and 1997-09-02
# processing data between 1987-10-14 and 1997-09-03
# processing data between 1987-10-15 and 1997-09-04
# processing data between 1987-10-16 and 1997-09-05
# processing data between 1987-10-19 and 1997-09-08
# processing data between 1987-10-20 and 1997-09-09
# processing data between 1987-10-21 and 1997-09-10
# processing data between 1987-10-22 and 1997-09-11
# processing data between 1987-10-23 and 1997-09-12
# processing data between 1987-10-26 and 1997-09-15
# processing data between 1987-10-27 and 1997-09-16
# processing data between 1987-10-28 and 1997-09-17
# processing data between 1987-10-29 and 1997-09-18
# processing data between 1987-10-30 and 1997-09-19
# processing data between 1987-11-02 and 1997-09-22
# processing data between 1987-11-03 and 1997-09-23
# processing data between 1987-11-04 and 1997-09-24
# processing data between 1987-11-05 and 1997-09-25
# processing data between 1987-11-06 and 1997-09-26
# processing data between 1987-11-09 and 1997-09-29
# processing data between 1987-11-10 and 1997-09-30
# processing data between 1987-11-11 and 1997-10-01
# processing data between 1987-11-12 and 1997-10-02
# processing data between 1987-11-13 and 1997-10-03
# processing data between 1987-11-16 and 1997-10-06
# processing data between 1987-11-17 and 1997-10-07
# processing data between 1987-11-18 and 1997-10-08
# processing data between 1987-11-19 and 1997-10-09
# processing data between 1987-11-20 and 1997-10-10
# processing data between 1987-11-23 and 1997-10-13
# processing data between 1987-11-24 and 1997-10-14
# processing data between 1987-11-25 and 1997-10-15
# processing data between 1987-11-27 and 1997-10-16
# processing data between 1987-11-30 and 1997-10-17
# processing data between 1987-12-01 and 1997-10-20
# processing data between 1987-12-02 and 1997-10-21
# processing data between 1987-12-03 and 1997-10-22
# processing data between 1987-12-04 and 1997-10-23
# processing data between 1987-12-07 and 1997-10-24
# processing data between 1987-12-08 and 1997-10-27
# processing data between 1987-12-09 and 1997-10-28
# processing data between 1987-12-10 and 1997-10-29
# processing data between 1987-12-11 and 1997-10-30
# processing data between 1987-12-14 and 1997-10-31
# processing data between 1987-12-15 and 1997-11-03
# processing data between 1987-12-16 and 1997-11-04
# processing data between 1987-12-17 and 1997-11-05
# processing data between 1987-12-18 and 1997-11-06
# processing data between 1987-12-21 and 1997-11-07
# processing data between 1987-12-22 and 1997-11-10
# processing data between 1987-12-23 and 1997-11-11
# processing data between 1987-12-24 and 1997-11-12
# processing data between 1987-12-28 and 1997-11-13
# processing data between 1987-12-29 and 1997-11-14
# processing data between 1987-12-30 and 1997-11-17
# processing data between 1987-12-31 and 1997-11-18
# processing data between 1988-01-04 and 1997-11-19
# processing data between 1988-01-05 and 1997-11-20
# processing data between 1988-01-06 and 1997-11-21
# processing data between 1988-01-07 and 1997-11-24
# processing data between 1988-01-08 and 1997-11-25
# processing data between 1988-01-11 and 1997-11-26
# processing data between 1988-01-12 and 1997-11-28
# processing data between 1988-01-13 and 1997-12-01
# processing data between 1988-01-14 and 1997-12-02
# processing data between 1988-01-15 and 1997-12-03
# processing data between 1988-01-18 and 1997-12-04
# processing data between 1988-01-19 and 1997-12-05
# processing data between 1988-01-20 and 1997-12-08
# processing data between 1988-01-21 and 1997-12-09
# processing data between 1988-01-22 and 1997-12-10
# processing data between 1988-01-25 and 1997-12-11
# processing data between 1988-01-26 and 1997-12-12
# processing data between 1988-01-27 and 1997-12-15
# processing data between 1988-01-28 and 1997-12-16
# processing data between 1988-01-29 and 1997-12-17
# processing data between 1988-02-01 and 1997-12-18
# processing data between 1988-02-02 and 1997-12-19
# processing data between 1988-02-03 and 1997-12-22
# processing data between 1988-02-04 and 1997-12-23
# processing data between 1988-02-05 and 1997-12-24
# processing data between 1988-02-08 and 1997-12-26
# processing data between 1988-02-09 and 1997-12-29
# processing data between 1988-02-10 and 1997-12-30
# processing data between 1988-02-11 and 1997-12-31
# processing data between 1988-02-12 and 1998-01-02
# processing data between 1988-02-16 and 1998-01-05
# processing data between 1988-02-17 and 1998-01-06
# processing data between 1988-02-18 and 1998-01-07
# processing data between 1988-02-19 and 1998-01-08
# processing data between 1988-02-22 and 1998-01-09
# processing data between 1988-02-23 and 1998-01-12
# processing data between 1988-02-24 and 1998-01-13
# processing data between 1988-02-25 and 1998-01-14
# processing data between 1988-02-26 and 1998-01-15
# processing data between 1988-02-29 and 1998-01-16
# processing data between 1988-03-01 and 1998-01-20
# processing data between 1988-03-02 and 1998-01-21
# processing data between 1988-03-03 and 1998-01-22
# processing data between 1988-03-04 and 1998-01-23
# processing data between 1988-03-07 and 1998-01-26
# processing data between 1988-03-08 and 1998-01-27
# processing data between 1988-03-09 and 1998-01-28
# processing data between 1988-03-10 and 1998-01-29
# processing data between 1988-03-11 and 1998-01-30
# processing data between 1988-03-14 and 1998-02-02
# processing data between 1988-03-15 and 1998-02-03
# processing data between 1988-03-16 and 1998-02-04
# processing data between 1988-03-17 and 1998-02-05
# processing data between 1988-03-18 and 1998-02-06
# processing data between 1988-03-21 and 1998-02-09
# processing data between 1988-03-22 and 1998-02-10
# processing data between 1988-03-23 and 1998-02-11
# processing data between 1988-03-24 and 1998-02-12
# processing data between 1988-03-25 and 1998-02-13
# processing data between 1988-03-28 and 1998-02-17
# processing data between 1988-03-29 and 1998-02-18
# processing data between 1988-03-30 and 1998-02-19
# processing data between 1988-03-31 and 1998-02-20
# processing data between 1988-04-04 and 1998-02-23
# processing data between 1988-04-05 and 1998-02-24
# processing data between 1988-04-06 and 1998-02-25
# processing data between 1988-04-07 and 1998-02-26
# processing data between 1988-04-08 and 1998-02-27
# processing data between 1988-04-11 and 1998-03-02
# processing data between 1988-04-12 and 1998-03-03
# processing data between 1988-04-13 and 1998-03-04
# processing data between 1988-04-14 and 1998-03-05
# processing data between 1988-04-15 and 1998-03-06
# processing data between 1988-04-18 and 1998-03-09
# processing data between 1988-04-19 and 1998-03-10
# processing data between 1988-04-20 and 1998-03-11
# processing data between 1988-04-21 and 1998-03-12
# processing data between 1988-04-22 and 1998-03-13
# processing data between 1988-04-25 and 1998-03-16
# processing data between 1988-04-26 and 1998-03-17
# processing data between 1988-04-27 and 1998-03-18
# processing data between 1988-04-28 and 1998-03-19
# processing data between 1988-04-29 and 1998-03-20
# processing data between 1988-05-02 and 1998-03-23
# processing data between 1988-05-03 and 1998-03-24
# processing data between 1988-05-04 and 1998-03-25
# processing data between 1988-05-05 and 1998-03-26
# processing data between 1988-05-06 and 1998-03-27
# processing data between 1988-05-09 and 1998-03-30
# processing data between 1988-05-10 and 1998-03-31
# processing data between 1988-05-11 and 1998-04-01
# processing data between 1988-05-12 and 1998-04-02
# processing data between 1988-05-13 and 1998-04-03
# processing data between 1988-05-16 and 1998-04-06
# processing data between 1988-05-17 and 1998-04-07
# processing data between 1988-05-18 and 1998-04-08
# processing data between 1988-05-19 and 1998-04-09
# processing data between 1988-05-20 and 1998-04-13
# processing data between 1988-05-23 and 1998-04-14
# processing data between 1988-05-24 and 1998-04-15
# processing data between 1988-05-25 and 1998-04-16
# processing data between 1988-05-26 and 1998-04-17
# processing data between 1988-05-27 and 1998-04-20
# processing data between 1988-05-31 and 1998-04-21
# processing data between 1988-06-01 and 1998-04-22
# processing data between 1988-06-02 and 1998-04-23
# processing data between 1988-06-03 and 1998-04-24
# processing data between 1988-06-06 and 1998-04-27
# processing data between 1988-06-07 and 1998-04-28
# processing data between 1988-06-08 and 1998-04-29
# processing data between 1988-06-09 and 1998-04-30
# processing data between 1988-06-10 and 1998-05-01
# processing data between 1988-06-13 and 1998-05-04
# processing data between 1988-06-14 and 1998-05-05
# processing data between 1988-06-15 and 1998-05-06
# processing data between 1988-06-16 and 1998-05-07
# processing data between 1988-06-17 and 1998-05-08
# processing data between 1988-06-20 and 1998-05-11
# processing data between 1988-06-21 and 1998-05-12
# processing data between 1988-06-22 and 1998-05-13
# processing data between 1988-06-23 and 1998-05-14
# processing data between 1988-06-24 and 1998-05-15
# processing data between 1988-06-27 and 1998-05-18
# processing data between 1988-06-28 and 1998-05-19
# processing data between 1988-06-29 and 1998-05-20
# processing data between 1988-06-30 and 1998-05-21
# processing data between 1988-07-01 and 1998-05-22
# processing data between 1988-07-05 and 1998-05-26
# processing data between 1988-07-06 and 1998-05-27
# processing data between 1988-07-07 and 1998-05-28
# processing data between 1988-07-08 and 1998-05-29
# processing data between 1988-07-11 and 1998-06-01
# processing data between 1988-07-12 and 1998-06-02
# processing data between 1988-07-13 and 1998-06-03
# processing data between 1988-07-14 and 1998-06-04
# processing data between 1988-07-15 and 1998-06-05
# processing data between 1988-07-18 and 1998-06-08
# processing data between 1988-07-19 and 1998-06-09
# processing data between 1988-07-20 and 1998-06-10
# processing data between 1988-07-21 and 1998-06-11
# processing data between 1988-07-22 and 1998-06-12
# processing data between 1988-07-25 and 1998-06-15
# processing data between 1988-07-26 and 1998-06-16
# processing data between 1988-07-27 and 1998-06-17
# processing data between 1988-07-28 and 1998-06-18
# processing data between 1988-07-29 and 1998-06-19
# processing data between 1988-08-01 and 1998-06-22
# processing data between 1988-08-02 and 1998-06-23
# processing data between 1988-08-03 and 1998-06-24
# processing data between 1988-08-04 and 1998-06-25
# processing data between 1988-08-05 and 1998-06-26
# processing data between 1988-08-08 and 1998-06-29
# processing data between 1988-08-09 and 1998-06-30
# processing data between 1988-08-10 and 1998-07-01
# processing data between 1988-08-11 and 1998-07-02
# processing data between 1988-08-12 and 1998-07-06
# processing data between 1988-08-15 and 1998-07-07
# processing data between 1988-08-16 and 1998-07-08
# processing data between 1988-08-17 and 1998-07-09
# processing data between 1988-08-18 and 1998-07-10
# processing data between 1988-08-19 and 1998-07-13
# processing data between 1988-08-22 and 1998-07-14
# processing data between 1988-08-23 and 1998-07-15
# processing data between 1988-08-24 and 1998-07-16
# processing data between 1988-08-25 and 1998-07-17
# processing data between 1988-08-26 and 1998-07-20
# processing data between 1988-08-29 and 1998-07-21
# processing data between 1988-08-30 and 1998-07-22
# processing data between 1988-08-31 and 1998-07-23
# processing data between 1988-09-01 and 1998-07-24
# processing data between 1988-09-02 and 1998-07-27
# processing data between 1988-09-06 and 1998-07-28
# processing data between 1988-09-07 and 1998-07-29
# processing data between 1988-09-08 and 1998-07-30
# processing data between 1988-09-09 and 1998-07-31
# processing data between 1988-09-12 and 1998-08-03
# processing data between 1988-09-13 and 1998-08-04
# processing data between 1988-09-14 and 1998-08-05
# processing data between 1988-09-15 and 1998-08-06
# processing data between 1988-09-16 and 1998-08-07
# processing data between 1988-09-19 and 1998-08-10
# processing data between 1988-09-20 and 1998-08-11
# processing data between 1988-09-21 and 1998-08-12
# processing data between 1988-09-22 and 1998-08-13
# processing data between 1988-09-23 and 1998-08-14
# processing data between 1988-09-26 and 1998-08-17
# processing data between 1988-09-27 and 1998-08-18
# processing data between 1988-09-28 and 1998-08-19
# processing data between 1988-09-29 and 1998-08-20
# processing data between 1988-09-30 and 1998-08-21
# processing data between 1988-10-03 and 1998-08-24
# processing data between 1988-10-04 and 1998-08-25
# processing data between 1988-10-05 and 1998-08-26
# processing data between 1988-10-06 and 1998-08-27
# processing data between 1988-10-07 and 1998-08-28
# processing data between 1988-10-10 and 1998-08-31
# processing data between 1988-10-11 and 1998-09-01
# processing data between 1988-10-12 and 1998-09-02
# processing data between 1988-10-13 and 1998-09-03
# processing data between 1988-10-14 and 1998-09-04
# processing data between 1988-10-17 and 1998-09-08
# processing data between 1988-10-18 and 1998-09-09
# processing data between 1988-10-19 and 1998-09-10
# processing data between 1988-10-20 and 1998-09-11
# processing data between 1988-10-21 and 1998-09-14
# processing data between 1988-10-24 and 1998-09-15
# processing data between 1988-10-25 and 1998-09-16
# processing data between 1988-10-26 and 1998-09-17
# processing data between 1988-10-27 and 1998-09-18
# processing data between 1988-10-28 and 1998-09-21
# processing data between 1988-10-31 and 1998-09-22
# processing data between 1988-11-01 and 1998-09-23
# processing data between 1988-11-02 and 1998-09-24
# processing data between 1988-11-03 and 1998-09-25
# processing data between 1988-11-04 and 1998-09-28
# processing data between 1988-11-07 and 1998-09-29
# processing data between 1988-11-08 and 1998-09-30
# processing data between 1988-11-09 and 1998-10-01
# processing data between 1988-11-10 and 1998-10-02
# processing data between 1988-11-11 and 1998-10-05
# processing data between 1988-11-14 and 1998-10-06
# processing data between 1988-11-15 and 1998-10-07
# processing data between 1988-11-16 and 1998-10-08
# processing data between 1988-11-17 and 1998-10-09
# processing data between 1988-11-18 and 1998-10-12
# processing data between 1988-11-21 and 1998-10-13
# processing data between 1988-11-22 and 1998-10-14
# processing data between 1988-11-23 and 1998-10-15
# processing data between 1988-11-25 and 1998-10-16
# processing data between 1988-11-28 and 1998-10-19
# processing data between 1988-11-29 and 1998-10-20
# processing data between 1988-11-30 and 1998-10-21
# processing data between 1988-12-01 and 1998-10-22
# processing data between 1988-12-02 and 1998-10-23
# processing data between 1988-12-05 and 1998-10-26
# processing data between 1988-12-06 and 1998-10-27
# processing data between 1988-12-07 and 1998-10-28
# processing data between 1988-12-08 and 1998-10-29
# processing data between 1988-12-09 and 1998-10-30
# processing data between 1988-12-12 and 1998-11-02
# processing data between 1988-12-13 and 1998-11-03
# processing data between 1988-12-14 and 1998-11-04
# processing data between 1988-12-15 and 1998-11-05
# processing data between 1988-12-16 and 1998-11-06
# processing data between 1988-12-19 and 1998-11-09
# processing data between 1988-12-20 and 1998-11-10
# processing data between 1988-12-21 and 1998-11-11
# processing data between 1988-12-22 and 1998-11-12
# processing data between 1988-12-23 and 1998-11-13
# processing data between 1988-12-27 and 1998-11-16
# processing data between 1988-12-28 and 1998-11-17
# processing data between 1988-12-29 and 1998-11-18
# processing data between 1988-12-30 and 1998-11-19
# processing data between 1989-01-03 and 1998-11-20
# processing data between 1989-01-04 and 1998-11-23
# processing data between 1989-01-05 and 1998-11-24
# processing data between 1989-01-06 and 1998-11-25
# processing data between 1989-01-09 and 1998-11-27
# processing data between 1989-01-10 and 1998-11-30
# processing data between 1989-01-11 and 1998-12-01
# processing data between 1989-01-12 and 1998-12-02
# processing data between 1989-01-13 and 1998-12-03
# processing data between 1989-01-16 and 1998-12-04
# processing data between 1989-01-17 and 1998-12-07
# processing data between 1989-01-18 and 1998-12-08
# processing data between 1989-01-19 and 1998-12-09
# processing data between 1989-01-20 and 1998-12-10
# processing data between 1989-01-23 and 1998-12-11
# processing data between 1989-01-24 and 1998-12-14
# processing data between 1989-01-25 and 1998-12-15
# processing data between 1989-01-26 and 1998-12-16
# processing data between 1989-01-27 and 1998-12-17
# processing data between 1989-01-30 and 1998-12-18
# processing data between 1989-01-31 and 1998-12-21
# processing data between 1989-02-01 and 1998-12-22
# processing data between 1989-02-02 and 1998-12-23
# processing data between 1989-02-03 and 1998-12-24
# processing data between 1989-02-06 and 1998-12-28
# processing data between 1989-02-07 and 1998-12-29
# processing data between 1989-02-08 and 1998-12-30
# processing data between 1989-02-09 and 1998-12-31
# processing data between 1989-02-10 and 1999-01-04
# processing data between 1989-02-13 and 1999-01-05
# processing data between 1989-02-14 and 1999-01-06
# processing data between 1989-02-15 and 1999-01-07
# processing data between 1989-02-16 and 1999-01-08
# processing data between 1989-02-17 and 1999-01-11
# processing data between 1989-02-21 and 1999-01-12
# processing data between 1989-02-22 and 1999-01-13
# processing data between 1989-02-23 and 1999-01-14
# processing data between 1989-02-24 and 1999-01-15
# processing data between 1989-02-27 and 1999-01-19
# processing data between 1989-02-28 and 1999-01-20
# processing data between 1989-03-01 and 1999-01-21
# processing data between 1989-03-02 and 1999-01-22
# processing data between 1989-03-03 and 1999-01-25
# processing data between 1989-03-06 and 1999-01-26
# processing data between 1989-03-07 and 1999-01-27
# processing data between 1989-03-08 and 1999-01-28
# processing data between 1989-03-09 and 1999-01-29
# processing data between 1989-03-10 and 1999-02-01
# processing data between 1989-03-13 and 1999-02-02
# processing data between 1989-03-14 and 1999-02-03
# processing data between 1989-03-15 and 1999-02-04
# processing data between 1989-03-16 and 1999-02-05
# processing data between 1989-03-17 and 1999-02-08
# processing data between 1989-03-20 and 1999-02-09
# processing data between 1989-03-21 and 1999-02-10
# processing data between 1989-03-22 and 1999-02-11
# processing data between 1989-03-23 and 1999-02-12
# processing data between 1989-03-27 and 1999-02-16
# processing data between 1989-03-28 and 1999-02-17
# processing data between 1989-03-29 and 1999-02-18
# processing data between 1989-03-30 and 1999-02-19
# processing data between 1989-03-31 and 1999-02-22
# processing data between 1989-04-03 and 1999-02-23
# processing data between 1989-04-04 and 1999-02-24
# processing data between 1989-04-05 and 1999-02-25
# processing data between 1989-04-06 and 1999-02-26
# processing data between 1989-04-07 and 1999-03-01
# processing data between 1989-04-10 and 1999-03-02
# processing data between 1989-04-11 and 1999-03-03
# processing data between 1989-04-12 and 1999-03-04
# processing data between 1989-04-13 and 1999-03-05
# processing data between 1989-04-14 and 1999-03-08
# processing data between 1989-04-17 and 1999-03-09
# processing data between 1989-04-18 and 1999-03-10
# processing data between 1989-04-19 and 1999-03-11
# processing data between 1989-04-20 and 1999-03-12
# processing data between 1989-04-21 and 1999-03-15
# processing data between 1989-04-24 and 1999-03-16
# processing data between 1989-04-25 and 1999-03-17
# processing data between 1989-04-26 and 1999-03-18
# processing data between 1989-04-27 and 1999-03-19
# processing data between 1989-04-28 and 1999-03-22
# processing data between 1989-05-01 and 1999-03-23
# processing data between 1989-05-02 and 1999-03-24
# processing data between 1989-05-03 and 1999-03-25
# processing data between 1989-05-04 and 1999-03-26
# processing data between 1989-05-05 and 1999-03-29
# processing data between 1989-05-08 and 1999-03-30
# processing data between 1989-05-09 and 1999-03-31
# processing data between 1989-05-10 and 1999-04-01
# processing data between 1989-05-11 and 1999-04-05
# processing data between 1989-05-12 and 1999-04-06
# processing data between 1989-05-15 and 1999-04-07
# processing data between 1989-05-16 and 1999-04-08
# processing data between 1989-05-17 and 1999-04-09
# processing data between 1989-05-18 and 1999-04-12
# processing data between 1989-05-19 and 1999-04-13
# processing data between 1989-05-22 and 1999-04-14
# processing data between 1989-05-23 and 1999-04-15
# processing data between 1989-05-24 and 1999-04-16
# processing data between 1989-05-25 and 1999-04-19
# processing data between 1989-05-26 and 1999-04-20
# processing data between 1989-05-30 and 1999-04-21
# processing data between 1989-05-31 and 1999-04-22
# processing data between 1989-06-01 and 1999-04-23
# processing data between 1989-06-02 and 1999-04-26
# processing data between 1989-06-05 and 1999-04-27
# processing data between 1989-06-06 and 1999-04-28
# processing data between 1989-06-07 and 1999-04-29
# processing data between 1989-06-08 and 1999-04-30
# processing data between 1989-06-09 and 1999-05-03
# processing data between 1989-06-12 and 1999-05-04
# processing data between 1989-06-13 and 1999-05-05
# processing data between 1989-06-14 and 1999-05-06
# processing data between 1989-06-15 and 1999-05-07
# processing data between 1989-06-16 and 1999-05-10
# processing data between 1989-06-19 and 1999-05-11
# processing data between 1989-06-20 and 1999-05-12
# processing data between 1989-06-21 and 1999-05-13
# processing data between 1989-06-22 and 1999-05-14
# processing data between 1989-06-23 and 1999-05-17
# processing data between 1989-06-26 and 1999-05-18
# processing data between 1989-06-27 and 1999-05-19
# processing data between 1989-06-28 and 1999-05-20
# processing data between 1989-06-29 and 1999-05-21
# processing data between 1989-06-30 and 1999-05-24
# processing data between 1989-07-03 and 1999-05-25
# processing data between 1989-07-05 and 1999-05-26
# processing data between 1989-07-06 and 1999-05-27
# processing data between 1989-07-07 and 1999-05-28
# processing data between 1989-07-10 and 1999-06-01
# processing data between 1989-07-11 and 1999-06-02
# processing data between 1989-07-12 and 1999-06-03
# processing data between 1989-07-13 and 1999-06-04
# processing data between 1989-07-14 and 1999-06-07
# processing data between 1989-07-17 and 1999-06-08
# processing data between 1989-07-18 and 1999-06-09
# processing data between 1989-07-19 and 1999-06-10
# ...
# processing data between 1994-11-23 and 2004-10-28
# processing data between 1994-11-25 and 2004-10-29
# processing data between 1994-11-28 and 2004-11-01
# processing data between 1994-11-29 and 2004-11-02
# processing data between 1994-11-30 and 2004-11-03
# processing data between 1994-12-01 and 2004-11-04
# processing data between 1994-12-02 and 2004-11-05
# processing data between 1994-12-05 and 2004-11-08
# processing data between 1994-12-06 and 2004-11-09
# processing data between 1994-12-07 and 2004-11-10
# processing data between 1994-12-08 and 2004-11-11
# processing data between 1994-12-09 and 2004-11-12
# processing data between 1994-12-12 and 2004-11-15
# processing data between 1994-12-13 and 2004-11-16
# processing data between 1994-12-14 and 2004-11-17
# processing data between 1994-12-15 and 2004-11-18
# processing data between 1994-12-16 and 2004-11-19
# processing data between 1994-12-19 and 2004-11-22
# processing data between 1994-12-20 and 2004-11-23
# processing data between 1994-12-21 and 2004-11-24
# processing data between 1994-12-22 and 2004-11-26
# processing data between 1994-12-23 and 2004-11-29
# processing data between 1994-12-27 and 2004-11-30
# processing data between 1994-12-28 and 2004-12-01
# processing data between 1994-12-29 and 2004-12-02
# processing data between 1994-12-30 and 2004-12-03
# processing data between 1995-01-03 and 2004-12-06
# processing data between 1995-01-04 and 2004-12-07
# processing data between 1995-01-05 and 2004-12-08
# processing data between 1995-01-06 and 2004-12-09
# processing data between 1995-01-09 and 2004-12-10
# processing data between 1995-01-10 and 2004-12-13
# processing data between 1995-01-11 and 2004-12-14
# processing data between 1995-01-12 and 2004-12-15
# processing data between 1995-01-13 and 2004-12-16
# processing data between 1995-01-16 and 2004-12-17
# processing data between 1995-01-17 and 2004-12-20
# processing data between 1995-01-18 and 2004-12-21
# processing data between 1995-01-19 and 2004-12-22
# processing data between 1995-01-20 and 2004-12-23
# processing data between 1995-01-23 and 2004-12-27
# processing data between 1995-01-24 and 2004-12-28
# processing data between 1995-01-25 and 2004-12-29
# processing data between 1995-01-26 and 2004-12-30
# processing data between 1995-01-27 and 2004-12-31
# processing data between 1995-01-30 and 2005-01-03
# processing data between 1995-01-31 and 2005-01-04
# processing data between 1995-02-01 and 2005-01-05
# processing data between 1995-02-02 and 2005-01-06
# processing data between 1995-02-03 and 2005-01-07
# processing data between 1995-02-06 and 2005-01-10
# processing data between 1995-02-07 and 2005-01-11
# processing data between 1995-02-08 and 2005-01-12
# processing data between 1995-02-09 and 2005-01-13
# processing data between 1995-02-10 and 2005-01-14
# processing data between 1995-02-13 and 2005-01-18
# processing data between 1995-02-14 and 2005-01-19
# processing data between 1995-02-15 and 2005-01-20
# processing data between 1995-02-16 and 2005-01-21
# processing data between 1995-02-17 and 2005-01-24
# processing data between 1995-02-21 and 2005-01-25
# processing data between 1995-02-22 and 2005-01-26
# processing data between 1995-02-23 and 2005-01-27
# processing data between 1995-02-24 and 2005-01-28
# processing data between 1995-02-27 and 2005-01-31
# processing data between 1995-02-28 and 2005-02-01
# processing data between 1995-03-01 and 2005-02-02
# processing data between 1995-03-02 and 2005-02-03
# processing data between 1995-03-03 and 2005-02-04
# processing data between 1995-03-06 and 2005-02-07
# processing data between 1995-03-07 and 2005-02-08
# processing data between 1995-03-08 and 2005-02-09
# processing data between 1995-03-09 and 2005-02-10
# processing data between 1995-03-10 and 2005-02-11
# processing data between 1995-03-13 and 2005-02-14
# processing data between 1995-03-14 and 2005-02-15
# processing data between 1995-03-15 and 2005-02-16
# processing data between 1995-03-16 and 2005-02-17
# processing data between 1995-03-17 and 2005-02-18
# processing data between 1995-03-20 and 2005-02-22
# processing data between 1995-03-21 and 2005-02-23
# processing data between 1995-03-22 and 2005-02-24
# processing data between 1995-03-23 and 2005-02-25
# processing data between 1995-03-24 and 2005-02-28
# processing data between 1995-03-27 and 2005-03-01
# processing data between 1995-03-28 and 2005-03-02
# processing data between 1995-03-29 and 2005-03-03
# processing data between 1995-03-30 and 2005-03-04
# processing data between 1995-03-31 and 2005-03-07
# processing data between 1995-04-03 and 2005-03-08
# processing data between 1995-04-04 and 2005-03-09
# processing data between 1995-04-05 and 2005-03-10
# processing data between 1995-04-06 and 2005-03-11
# processing data between 1995-04-07 and 2005-03-14
# processing data between 1995-04-10 and 2005-03-15
# processing data between 1995-04-11 and 2005-03-16
# processing data between 1995-04-12 and 2005-03-17
# processing data between 1995-04-13 and 2005-03-18
# processing data between 1995-04-17 and 2005-03-21
# processing data between 1995-04-18 and 2005-03-22
# processing data between 1995-04-19 and 2005-03-23
# processing data between 1995-04-20 and 2005-03-24
# processing data between 1995-04-21 and 2005-03-28
# processing data between 1995-04-24 and 2005-03-29
# processing data between 1995-04-25 and 2005-03-30
# processing data between 1995-04-26 and 2005-03-31
# processing data between 1995-04-27 and 2005-04-01
# processing data between 1995-04-28 and 2005-04-04
# processing data between 1995-05-01 and 2005-04-05
# processing data between 1995-05-02 and 2005-04-06
# processing data between 1995-05-03 and 2005-04-07
# processing data between 1995-05-04 and 2005-04-08
# processing data between 1995-05-05 and 2005-04-11
# processing data between 1995-05-08 and 2005-04-12
# processing data between 1995-05-09 and 2005-04-13
# processing data between 1995-05-10 and 2005-04-14
# processing data between 1995-05-11 and 2005-04-15
# processing data between 1995-05-12 and 2005-04-18
# processing data between 1995-05-15 and 2005-04-19
# processing data between 1995-05-16 and 2005-04-20
# processing data between 1995-05-17 and 2005-04-21
# processing data between 1995-05-18 and 2005-04-22
# processing data between 1995-05-19 and 2005-04-25
# processing data between 1995-05-22 and 2005-04-26
# processing data between 1995-05-23 and 2005-04-27
# processing data between 1995-05-24 and 2005-04-28
# processing data between 1995-05-25 and 2005-04-29
# processing data between 1995-05-26 and 2005-05-02
# processing data between 1995-05-30 and 2005-05-03
# processing data between 1995-05-31 and 2005-05-04
# processing data between 1995-06-01 and 2005-05-05
# processing data between 1995-06-02 and 2005-05-06
# processing data between 1995-06-05 and 2005-05-09
# processing data between 1995-06-06 and 2005-05-10
# processing data between 1995-06-07 and 2005-05-11
# processing data between 1995-06-08 and 2005-05-12
# processing data between 1995-06-09 and 2005-05-13
# processing data between 1995-06-12 and 2005-05-16
# processing data between 1995-06-13 and 2005-05-17
# processing data between 1995-06-14 and 2005-05-18
# processing data between 1995-06-15 and 2005-05-19
# processing data between 1995-06-16 and 2005-05-20
# processing data between 1995-06-19 and 2005-05-23
# processing data between 1995-06-20 and 2005-05-24
# processing data between 1995-06-21 and 2005-05-25
# processing data between 1995-06-22 and 2005-05-26
# processing data between 1995-06-23 and 2005-05-27
# processing data between 1995-06-26 and 2005-05-31
# processing data between 1995-06-27 and 2005-06-01
# processing data between 1995-06-28 and 2005-06-02
# processing data between 1995-06-29 and 2005-06-03
# processing data between 1995-06-30 and 2005-06-06
# processing data between 1995-07-03 and 2005-06-07
# processing data between 1995-07-05 and 2005-06-08
# processing data between 1995-07-06 and 2005-06-09
# processing data between 1995-07-07 and 2005-06-10
# processing data between 1995-07-10 and 2005-06-13
# processing data between 1995-07-11 and 2005-06-14
# processing data between 1995-07-12 and 2005-06-15
# processing data between 1995-07-13 and 2005-06-16
# processing data between 1995-07-14 and 2005-06-17
# processing data between 1995-07-17 and 2005-06-20
# processing data between 1995-07-18 and 2005-06-21
# processing data between 1995-07-19 and 2005-06-22
# processing data between 1995-07-20 and 2005-06-23
# processing data between 1995-07-21 and 2005-06-24
# processing data between 1995-07-24 and 2005-06-27
# processing data between 1995-07-25 and 2005-06-28
# processing data between 1995-07-26 and 2005-06-29
# processing data between 1995-07-27 and 2005-06-30
# processing data between 1995-07-28 and 2005-07-01
# processing data between 1995-07-31 and 2005-07-05
# processing data between 1995-08-01 and 2005-07-06
# processing data between 1995-08-02 and 2005-07-07
# processing data between 1995-08-03 and 2005-07-08
# processing data between 1995-08-04 and 2005-07-11
# processing data between 1995-08-07 and 2005-07-12
# processing data between 1995-08-08 and 2005-07-13
# processing data between 1995-08-09 and 2005-07-14
# processing data between 1995-08-10 and 2005-07-15
# processing data between 1995-08-11 and 2005-07-18
# processing data between 1995-08-14 and 2005-07-19
# processing data between 1995-08-15 and 2005-07-20
# processing data between 1995-08-16 and 2005-07-21
# processing data between 1995-08-17 and 2005-07-22
# processing data between 1995-08-18 and 2005-07-25
# processing data between 1995-08-21 and 2005-07-26
# processing data between 1995-08-22 and 2005-07-27
# processing data between 1995-08-23 and 2005-07-28
# processing data between 1995-08-24 and 2005-07-29
# processing data between 1995-08-25 and 2005-08-01
# processing data between 1995-08-28 and 2005-08-02
# processing data between 1995-08-29 and 2005-08-03
# processing data between 1995-08-30 and 2005-08-04
# processing data between 1995-08-31 and 2005-08-05
# processing data between 1995-09-01 and 2005-08-08
# processing data between 1995-09-05 and 2005-08-09
# processing data between 1995-09-06 and 2005-08-10
# processing data between 1995-09-07 and 2005-08-11
# processing data between 1995-09-08 and 2005-08-12
# processing data between 1995-09-11 and 2005-08-15
# processing data between 1995-09-12 and 2005-08-16
# processing data between 1995-09-13 and 2005-08-17
# processing data between 1995-09-14 and 2005-08-18
# processing data between 1995-09-15 and 2005-08-19
# processing data between 1995-09-18 and 2005-08-22
# processing data between 1995-09-19 and 2005-08-23
# processing data between 1995-09-20 and 2005-08-24
# processing data between 1995-09-21 and 2005-08-25
# processing data between 1995-09-22 and 2005-08-26
# processing data between 1995-09-25 and 2005-08-29
# processing data between 1995-09-26 and 2005-08-30
# processing data between 1995-09-27 and 2005-08-31
# processing data between 1995-09-28 and 2005-09-01
# processing data between 1995-09-29 and 2005-09-02
# processing data between 1995-10-02 and 2005-09-06
# processing data between 1995-10-03 and 2005-09-07
# processing data between 1995-10-04 and 2005-09-08
# processing data between 1995-10-05 and 2005-09-09
# processing data between 1995-10-06 and 2005-09-12
# processing data between 1995-10-09 and 2005-09-13
# processing data between 1995-10-10 and 2005-09-14
# processing data between 1995-10-11 and 2005-09-15
# processing data between 1995-10-12 and 2005-09-16
# processing data between 1995-10-13 and 2005-09-19
# processing data between 1995-10-16 and 2005-09-20
# processing data between 1995-10-17 and 2005-09-21
# processing data between 1995-10-18 and 2005-09-22
# processing data between 1995-10-19 and 2005-09-23
# processing data between 1995-10-20 and 2005-09-26
# processing data between 1995-10-23 and 2005-09-27
# processing data between 1995-10-24 and 2005-09-28
# processing data between 1995-10-25 and 2005-09-29
# processing data between 1995-10-26 and 2005-09-30
# processing data between 1995-10-27 and 2005-10-03
# processing data between 1995-10-30 and 2005-10-04
# processing data between 1995-10-31 and 2005-10-05
# processing data between 1995-11-01 and 2005-10-06
# processing data between 1995-11-02 and 2005-10-07
# processing data between 1995-11-03 and 2005-10-10
# processing data between 1995-11-06 and 2005-10-11
# processing data between 1995-11-07 and 2005-10-12
# processing data between 1995-11-08 and 2005-10-13
# processing data between 1995-11-09 and 2005-10-14
# processing data between 1995-11-10 and 2005-10-17
# processing data between 1995-11-13 and 2005-10-18
# processing data between 1995-11-14 and 2005-10-19
# processing data between 1995-11-15 and 2005-10-20
# processing data between 1995-11-16 and 2005-10-21
# processing data between 1995-11-17 and 2005-10-24
# processing data between 1995-11-20 and 2005-10-25
# processing data between 1995-11-21 and 2005-10-26
# processing data between 1995-11-22 and 2005-10-27
# processing data between 1995-11-24 and 2005-10-28
# processing data between 1995-11-27 and 2005-10-31
# processing data between 1995-11-28 and 2005-11-01
# processing data between 1995-11-29 and 2005-11-02
# processing data between 1995-11-30 and 2005-11-03
# processing data between 1995-12-01 and 2005-11-04
# processing data between 1995-12-04 and 2005-11-07
# processing data between 1995-12-05 and 2005-11-08
# processing data between 1995-12-06 and 2005-11-09
# processing data between 1995-12-07 and 2005-11-10
# processing data between 1995-12-08 and 2005-11-11
# processing data between 1995-12-11 and 2005-11-14
# processing data between 1995-12-12 and 2005-11-15
# processing data between 1995-12-13 and 2005-11-16
# processing data between 1995-12-14 and 2005-11-17
# processing data between 1995-12-15 and 2005-11-18
# processing data between 1995-12-18 and 2005-11-21
# processing data between 1995-12-19 and 2005-11-22
# processing data between 1995-12-20 and 2005-11-23
# processing data between 1995-12-21 and 2005-11-25
# processing data between 1995-12-22 and 2005-11-28
# processing data between 1995-12-26 and 2005-11-29
# processing data between 1995-12-27 and 2005-11-30
# processing data between 1995-12-28 and 2005-12-01
# processing data between 1995-12-29 and 2005-12-02
# processing data between 1996-01-02 and 2005-12-05
# processing data between 1996-01-03 and 2005-12-06
# processing data between 1996-01-04 and 2005-12-07
# processing data between 1996-01-05 and 2005-12-08
# processing data between 1996-01-08 and 2005-12-09
# processing data between 1996-01-09 and 2005-12-12
# processing data between 1996-01-10 and 2005-12-13
# processing data between 1996-01-11 and 2005-12-14
# processing data between 1996-01-12 and 2005-12-15
# processing data between 1996-01-15 and 2005-12-16
# processing data between 1996-01-16 and 2005-12-19
# processing data between 1996-01-17 and 2005-12-20
# processing data between 1996-01-18 and 2005-12-21
# processing data between 1996-01-19 and 2005-12-22
# processing data between 1996-01-22 and 2005-12-23
# processing data between 1996-01-23 and 2005-12-27
# processing data between 1996-01-24 and 2005-12-28
# processing data between 1996-01-25 and 2005-12-29
# processing data between 1996-01-26 and 2005-12-30
# processing data between 1996-01-29 and 2006-01-03
# processing data between 1996-01-30 and 2006-01-04
# processing data between 1996-01-31 and 2006-01-05
# processing data between 1996-02-01 and 2006-01-06
# processing data between 1996-02-02 and 2006-01-09
# processing data between 1996-02-05 and 2006-01-10
# processing data between 1996-02-06 and 2006-01-11
# processing data between 1996-02-07 and 2006-01-12
# processing data between 1996-02-08 and 2006-01-13
# processing data between 1996-02-09 and 2006-01-17
# processing data between 1996-02-12 and 2006-01-18
# processing data between 1996-02-13 and 2006-01-19
# processing data between 1996-02-14 and 2006-01-20
# processing data between 1996-02-15 and 2006-01-23
# processing data between 1996-02-16 and 2006-01-24
# processing data between 1996-02-20 and 2006-01-25
# processing data between 1996-02-21 and 2006-01-26
# processing data between 1996-02-22 and 2006-01-27
# processing data between 1996-02-23 and 2006-01-30
# processing data between 1996-02-26 and 2006-01-31
# processing data between 1996-02-27 and 2006-02-01
# processing data between 1996-02-28 and 2006-02-02
# processing data between 1996-02-29 and 2006-02-03

# %% [markdown]
# END
