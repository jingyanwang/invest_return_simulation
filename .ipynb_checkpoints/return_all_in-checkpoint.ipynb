# %%
import os
import re
import pandas as pd
from pandasql import sqldf
import yfinance as yf

pysqldf = lambda q: sqldf(q, globals())

# %% [markdown]
# https://github.com/ranaroussi/yfinance

# %% [markdown]
# ETF = '^HSI'
# ETF = '^DJI'
# ETF = '^GSPC'
# ETF = '^NDX'

# %%
hold_duration_years = 20

# %%
# %run data_collection_GSPC.ipynb

# %%
hold_duration_days = 252*hold_duration_years

date_column = 'Date'
price_column = 'Close'

start_date = '0000-01-01'
end_date = '2025-01-01'

# %%
data
# Out:
#              Date         Open         High          Low        Close  \
# 0      1927-12-30    17.660000    17.660000    17.660000    17.660000
# 1      1928-01-03    17.760000    17.760000    17.760000    17.760000
# 2      1928-01-04    17.719999    17.719999    17.719999    17.719999
# 3      1928-01-05    17.549999    17.549999    17.549999    17.549999
# 4      1928-01-06    17.660000    17.660000    17.660000    17.660000
# ...           ...          ...          ...          ...          ...
# 23876  2023-01-19  3911.840088  3922.939941  3885.540039  3898.850098
# 23877  2023-01-20  3909.040039  3972.959961  3897.860107  3972.610107
# 23878  2023-01-23  3978.139893  4039.310059  3971.639893  4019.810059
# 23879  2023-01-24  4001.739990  4023.919922  3989.790039  4016.949951
# 23880  2023-01-25  3982.709961  4019.550049  3949.060059  4016.219971
#
#            Volume     id
# 0               0      0
# 1               0      1
# 2               0      2
# 3               0      3
# 4               0      4
# ...           ...    ...
# 23876  3991500000  23876
# 23877  4013360000  23877
# 23878  3945210000  23878
# 23879  3320430000  23879
# 23880  3724020000  23880
#
# [23881 rows x 7 columns]

# %% [markdown]
# data.to_excel(
#     f'{ETF}.xlsx',
#     index = False,
#     )
#
# data = pd.read_excel(f'{ETF}.xlsx',)

# %%
data = pysqldf(u"""
    select 
    id,
    {} as date,
    {} as price
    from data
    """.format(
    date_column, 
    price_column
   ))

data = pysqldf(u"""
    select *
    from data
    where date >= '{}' and date <= '{}'
    order by date asc
    """.format(
    start_date, 
    end_date))

# %%
data
# Out:
#           id        date        price
# 0          0  1927-12-30    17.660000
# 1          1  1928-01-03    17.760000
# 2          2  1928-01-04    17.719999
# 3          3  1928-01-05    17.549999
# 4          4  1928-01-06    17.660000
# ...      ...         ...          ...
# 23876  23876  2023-01-19  3898.850098
# 23877  23877  2023-01-20  3972.610107
# 23878  23878  2023-01-23  4019.810059
# 23879  23879  2023-01-24  4016.949951
# 23880  23880  2023-01-25  4016.219971
#
# [23881 rows x 3 columns]

# %% [markdown]
# # the return

# %%
holding = pysqldf(u"""
    select 
    data.date,
    data.price,
    pre_data.date as pre_date,
    pre_data.price as pre_price,
    data.price/pre_data.price as price_ratio
    from data
    join data as pre_data on pre_data.id+{} = data.id
    """.format(hold_duration_days))

# %%
holding = pysqldf(u"""
    select *,
    price_ratio -1 as return
    from holding
    """)

# %%
holding
# Out:
#              date        price    pre_date   pre_price  price_ratio    return
# 0      1953-03-25    26.100000  1927-12-30   17.660000     1.477916  0.477916
# 1      1953-03-26    25.950001  1928-01-03   17.760000     1.461149  0.461149
# 2      1953-03-27    25.990000  1928-01-04   17.719999     1.466704  0.466704
# 3      1953-03-30    25.610001  1928-01-05   17.549999     1.459259  0.459259
# 4      1953-03-31    25.290001  1928-01-06   17.660000     1.432050  0.432050
# ...           ...          ...         ...         ...          ...       ...
# 17576  2023-01-19  3898.850098  1998-01-06  966.580017     4.033655  3.033655
# 17577  2023-01-20  3972.610107  1998-01-07  964.000000     4.120965  3.120965
# 17578  2023-01-23  4019.810059  1998-01-08  956.049988     4.204602  3.204602
# 17579  2023-01-24  4016.949951  1998-01-09  927.690002     4.330056  3.330056
# 17580  2023-01-25  4016.219971  1998-01-12  939.210022     4.276168  3.276168
#
# [17581 rows x 6 columns]

# %%
holding.plot(x ='date', y=[
    'price', 
    'pre_price', 
    ], grid = True)
# Out:
# <AxesSubplot: xlabel='date'>

# %%
holding.plot(x ='date', y=[
    'price_ratio', 
    ], grid = True)
# Out:
# <AxesSubplot: xlabel='date'>

# %%
holding
# Out:
#              date        price    pre_date   pre_price  price_ratio    return
# 0      1953-03-25    26.100000  1927-12-30   17.660000     1.477916  0.477916
# 1      1953-03-26    25.950001  1928-01-03   17.760000     1.461149  0.461149
# 2      1953-03-27    25.990000  1928-01-04   17.719999     1.466704  0.466704
# 3      1953-03-30    25.610001  1928-01-05   17.549999     1.459259  0.459259
# 4      1953-03-31    25.290001  1928-01-06   17.660000     1.432050  0.432050
# ...           ...          ...         ...         ...          ...       ...
# 17576  2023-01-19  3898.850098  1998-01-06  966.580017     4.033655  3.033655
# 17577  2023-01-20  3972.610107  1998-01-07  964.000000     4.120965  3.120965
# 17578  2023-01-23  4019.810059  1998-01-08  956.049988     4.204602  3.204602
# 17579  2023-01-24  4016.949951  1998-01-09  927.690002     4.330056  3.330056
# 17580  2023-01-25  4016.219971  1998-01-12  939.210022     4.276168  3.276168
#
# [17581 rows x 6 columns]

# %%
holding.boxplot(column=['price_ratio'])
# Out:
# <AxesSubplot: >

# %%
price_ratio = holding['price_ratio'].median()

print('Ratio:\t%0.4f'%(price_ratio))
# Out:
# Ratio:	5.7181

# %%
return_mean = holding['return'].mean()

return_std = holding['return'].std()

print(f'return: {return_mean:0.4f} / {return_std:0.4f}')
# Out:
# return: 5.2110 / 3.0911

# %% [markdown]
# END
